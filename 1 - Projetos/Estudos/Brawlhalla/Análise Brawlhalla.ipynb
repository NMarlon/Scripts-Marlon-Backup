# %%
import matplotlib as mp
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./brawlhallastats.csv')
#df = pd.read_csv('./archive/data.csv')
#df = df.rename(columns={'defence': 'defense'})

df.head(5)
# Out:
#     legend  strength  dexterity  defense  speed     Weapon_1 Weapon_2
# 0      Ada         6          7        3      6       Pistol    Spear
# 1  Artemis         5          5        4      8  RocketLance   Scythe
# 2    Asuri         4          7        5      6        Katar    Sword
# 3    Azoth         7          5        6      4          Bow      Axe
# 4  Barraza         6          4        8      4          Axe   Pistol

# %%
df = df.drop('price', axis=1)
df = df.drop('gender', axis=1)
df = df.drop('impersn', axis=1)
df = df.drop('imhead', axis=1)
df = df.drop('datereleased', axis=1)

# %%
df['Liquid_stats'] = df['strength'] +df['dexterity']+df['defense']+df['speed']

df['st_def']=df['strength'] + df['defense']
df['sp_st']=df['speed']+df['strength']
df['dex_st']=df['strength']+df['dexterity']

df['sp_dex']=df['speed']+df['dexterity']
df['dex_def']=df['dexterity']+df['defense']
df['def_sp']=df['defense']+df['speed']




df.sort_values(by='def_sp', ascending=False)
# Out:
#          legend  strength  dexterity  defense  speed     Weapon_1  \
# 25       Lucien         3          5        6      8        Katar
# 20         Kaya         4          4        7      7        Spear
# 45       Ulgrim         6          3        7      6          Axe
# 30          Nix         4          5        7      6       Scythe
# 31         Onyx         5          4        8      5        Fists
# 39     Sentinel         5          4        7      6       Hammer
# 26       Magyar         5          4        9      4       Hammer
# 46          Val         4          5        6      7        Fists
# 47       Vector         5          4        6      7  RocketLance
# 15      Hattori         4          6        4      8        Sword
# 27         Mako         6          4        4      8        Katar
# 29       Mordex         6          4        5      7       Scythe
# 4       Barraza         6          4        8      4          Axe
# ...

# %% [markdown]
# Radar Chart
#
# Comparar quais têm em algum lugar o melhor requisito de cada tipo
#
# terminar de fazer para 3 combinações
